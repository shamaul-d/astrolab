# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

results = []
with open("SiC-All.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

for i,row in enumerate(results):
    results[i] = row[11], row[13]

data = []
for i,r in enumerate(results[1:]):
    data.append(r)

reals = []

for i in data:
    if i[0] != '' and i[1] != '' and i[0] != '12C/13C':
        reals.append((i[0], i[1]))

#print(reals)

d = [0] * len(reals)

for j, row in enumerate(reals):
    if row[0] != '12C/13C':
        d[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data = np.array(d)
#print(n_data)

# %%
results = []
with open("P060z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c13o = C12[:3606:50] / C13[:3606:50]
n14n15o =  N14[:3606:50] / N15[:3606:50]
o17o16o = O17[:3606:50] / O16[:3606:50]
o18o16o = O18[:3606:50] / O16[:3606:50]

c12c13b = C12[3606:4688:50] / C13[3606:4688:50]
n14n15b =  N14[3606:4688:50] / N15[3606:4688:50]
o17o16b = O17[3606:4688:50] / O16[3606:4688:50]
o18o16b = O18[3606:4688:50] / O16[3606:4688:50]

c12c13bs = C12[4688:4741:50] / C13[4688:4741:50]
n14n15bs =  N14[4688:4741:50] / N15[4688:4741:50]
o17o16bs = O17[4688:4741:50] / O16[4688:4741:50]
o18o16bs = O18[4688:4741:50] / O16[4688:4741:50]

c12c13ys = C12[4741:5183:50] / C13[4741:5183:50]
n14n15ys =  N14[4741:5183:50] / N15[4741:5183:50]
o17o16ys = O17[4741:5183:50] / O16[4741:5183:50]
o18o16ys = O18[4741:5183:50] / O16[4741:5183:50]

c12c13bs2 = C12[5183:5199:50] / C13[5183:5199:50]
n14n15bs2 =  N14[5183:5199:50] / N15[5183:5199:50]
o17o16bs2 = O17[5183:5199:50] / O16[5183:5199:50]
o18o16bs2 = O18[5183:5199:50] / O16[5183:5199:50]

c12c13wnl = C12[5199:8590:50] / C13[5199:8590:50]
n14n15wnl =  N14[5199:8590:50] / N15[5199:8590:50]
o17o16wnl = O17[5199:8590:50] / O16[5199:8590:50]
o18o16wnl = O18[5199:8590:50] / O16[5199:8590:50]

c12c13wne = C12[8590:11027:50] / C13[8590:11027:50]
n14n15wne =  N14[8590:11027:50] / N15[8590:11027:50]
o17o16wne = O17[8590:11027:50] / O16[8590:11027:50]
o18o16wne = O18[8590:11027:50] / O16[8590:11027:50]

c12c13wc = C12[11027:22264:50] / C13[11027:22264:50]
n14n15wc =  N14[11027:22264:50] / N15[11027:22264:50]
o17o16wc = O17[11027:22264:50] / O16[11027:22264:50]
o18o16wc = O18[11027:22264:50] / O16[11027:22264:50]

c12c13wo = C12[22264::50] / C13[22264::50]
n14n15wo =  N14[22264::50] / N15[22264::50]
o17o16wo = O17[22264::50] / O16[22264::50]
o18o16wo = O18[22264::50] / O16[22264::50]

#print(c12c13)
#print(c12c13[:,0])

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data[:,0], n_data[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(c12c13o, n14n15o, color='b', marker = '.', label="Nonrotating 60M Otype Star")
plt.scatter(c12c13b, n14n15b, color='g', marker = '.', label="Nonrotating 60M Btype Star")
plt.scatter(c12c13bs, n14n15bs, color='orange', marker = '.', label="Nonrotating 60M BSG Star")
plt.scatter(c12c13ys, n14n15ys, color='k', marker = '.', label="Nonrotating 60M YSG Star")
plt.scatter(c12c13bs2, n14n15bs2, color='m', marker = '.')
plt.scatter(c12c13wnl, n14n15wnl, color='purple', marker = '.', label="Nonrotating 60M WNL Star")
plt.scatter(c12c13wne, n14n15wne, color='pink', marker = '.', label="Nonrotating 60M WNE Star")
plt.scatter(c12c13wc, n14n15wc, color='brown', marker = '.', label="Nonrotating 60M WC Star")
plt.scatter(c12c13wo, n14n15wo, color='yellow', marker = '.', label="Nonrotating 60M WO Star")
#plt.scatter([90],[500], marker="^", label="ss") #ss
plt.xscale("log")
plt.yscale("log")

plt.xlim([0.1, 10000000000000])
plt.ylim([1, 100000000])

plt.legend()

plt.xlabel(r"$^{12}C/^{13}C$")
plt.ylabel(r"$^{14}N/^{15}N$")

plt.title("Nitrogen/Carbon Ratios")

#plt.savefig('presn100comp.jpg', bbox_inches='tight')

plt.show()

# %%
results2 = []
with open("oxide-silicate-all.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results2.append(row)

for i,row in enumerate(results2):
    results2[i] = row[9], row[11]


data2 = []
for i,r in enumerate(results2[1:]):
    data2.append(r)

reals2 = []

for i in data2:
    if i[0] != '' and i[1] != '' and i[0] != '17O/16O' and i[0] != 'not measured':
        reals2.append((i[0], i[1]))

#print(reals)

d2 = [0] * len(reals2)

for j, row in enumerate(reals2):
    if row[0] != '17O/16O':
        d2[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data2 = np.array(d2)
#print(n_data2)

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data2[:,0], n_data2[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(o17o16o, o18o16o, color='b', marker = '.', label="Nonrotating 60M Otype Star")
plt.scatter(o17o16b, o18o16b, color='g', marker = '.', label="Nonrotating 60M Btype Star")
plt.scatter(o17o16bs, o18o16bs, color='orange', marker = '.', label="Nonrotating 60M BSG Star")
plt.scatter(o17o16ys, o18o16ys, color='k', marker = '.', label="Nonrotating 60M YSG Star")
plt.scatter(o17o16bs2, o18o16bs2, color='m', marker = '.')
plt.scatter(o17o16wnl, o18o16wnl, color='purple', marker = '.', label="Nonrotating 60M WNL Star")
plt.scatter(o17o16wne, o18o16wne, color='pink', marker = '.', label="Nonrotating 60M WNE Star")
plt.scatter(o17o16wc, o18o16wc, color='brown', marker = '.', label="Nonrotating 60M WC Star")
plt.scatter(o17o16wo, o18o16wo, color='yellow', marker = '.', label="Nonrotating 60M WO Star")
#plt.scatter([90],[500], marker="^", label="ss") #ss
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.xlim([0.000000001, .1])
plt.ylim([0.0000001, .1])

plt.show()
