# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

results = []
with open("SiC-All.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

for i,row in enumerate(results):
    results[i] = row[11], row[13]

data = []
for i,r in enumerate(results[1:]):
    data.append(r)

reals = []

for i in data:
    if i[0] != '' and i[1] != '' and i[0] != '12C/13C':
        reals.append((i[0], i[1]))

#print(reals)

d = [0] * len(reals)

for j, row in enumerate(reals):
    if row[0] != '12C/13C':
        d[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data = np.array(d)
#print(n_data)

# %%
results = []
with open("P020z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1320o = C12/C13
n14n1520o = N14/N15
o17o1620o = O17/O16
o18o1620o = O18/O16

# %%
results = []
with open("P020z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1320r = C12/C13
n14n1520r = N14/N15
o17o1620r = O17/O16
o18o1620r = O18/O16

#print(C12[33608])

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P025z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1325o = C12/C13
n14n1525o = N14/N15
o17o1625o = O17/O16
o18o1625o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P025z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1325r = C12/C13
n14n1525r = N14/N15
o17o1625r = O17/O16
o18o1625r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P032z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1332o = C12/C13
n14n1532o = N14/N15
o17o1632o = O17/O16
o18o1632o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P032z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1332r = C12/C13
n14n1532r = N14/N15
o17o1632r = O17/O16
o18o1632r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P040z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1340o = C12/C13
n14n1540o = N14/N15
o17o1640o = O17/O16
o18o1640o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P040z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1340r = C12/C13
n14n1540r = N14/N15
o17o1640r = O17/O16
o18o1640r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P060z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1360o = C12/C13
n14n1560o = N14/N15
o17o1660o = O17/O16
o18o1660o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P060z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1360r = C12/C13
n14n1560r = N14/N15
o17o1660r = O17/O16
o18o1660r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P085z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1385o = C12/C13
n14n1585o = N14/N15
o17o1685o = O17/O16
o18o1685o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P085z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c1385r = C12/C13
n14n1585r = N14/N15
o17o1685r = O17/O16
o18o1685r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P120z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c13120o = C12/C13
n14n15120o = N14/N15
o17o16120o = O17/O16
o18o16120o = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
results = []
with open("P120z14S4_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c13120r = C12/C13
n14n15120r = N14/N15
o17o16120r = O17/O16
o18o16120r = O18/O16

#print(c12c13)
#print(c12c13[:,0])

# %%
cr= [52,57,61,42,97,50,61,82,79,58,52,55,35,5,13,3]
nr= [1230,3700,1250,1040,2000,1100,4600,1800,4280,880,3330,1320,660,640,900,3200]
o17r= [860,625,650,610,784,925,830,1200,1095,1800,930,820,870,1110,820,1060,1200,850,1250,1045,695,620,535,550,862,504,300,770]
o18r= [763,1094,735,606,727,1290,980,660,500,1220,875,560,562,700,725,830,850,1100,1224,1600,732,770,400,682,890,1250,500,650]
o17r = np.array(o17r)
o17r = 1/o17r
o18r = np.array(o18r)
o18r = 1/o18r

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data[:,0], n_data[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(c12c1320o[::25], n14n1520o[::25], color='b', marker = '.', label="Nonrotating 20M ")
plt.scatter(c12c1325o[::25], n14n1525o[::25], color='g', marker = '.', label="Nonrotating 25M ")
plt.scatter(c12c1332o[::25], n14n1532o[::25], color='orange', marker = '.', label="Nonrotating 32M ")
plt.scatter(c12c1340o[::25], n14n1540o[::25], color='k', marker = '.', label="Nonrotating 40M ")
plt.scatter(c12c1360o[::25], n14n1560o[::25], color='m', marker = '.', label="Nonrotating 60M ")
plt.scatter(c12c1385o[::25], n14n1585o[::25], color='purple', marker = '.', label="Nonrotating 85M ")
plt.scatter(c12c13120o[::25], n14n15120o[::25], color='lime', marker = '.', label="Nonrotating 120M ")
plt.scatter(c12c1320r[::25], n14n1520r[::25], color='darkslateblue', marker = '.', label="Rotating 20M ")
plt.scatter(c12c1325r[::25], n14n1525r[::25], color='darkgreen', marker = '.', label="Rotating 25M ")
plt.scatter(c12c1332r[::25], n14n1532r[::25], color='darkorange', marker = '.', label="Rotating 32M ")
plt.scatter(c12c1340r[::25], n14n1540r[::25], color='yellow', marker = '.', label="Rotating 40M ")
plt.scatter(c12c1360r[::25], n14n1560r[::25], color='darkviolet', marker = '.', label="Rotating 60M ")
plt.scatter(c12c1385r[::25], n14n1585r[::25], color='thistle', marker = '.', label="Rotating 85M ")
plt.scatter(c12c13120r[::25], n14n15120r[::25], color='dodgerblue', marker = '.', label="Rotating 120M ")
plt.scatter(cr, nr, color="cyan", marker='.', label="AGB Carbon Stars")
#plt.scatter([90],[250], marker="^", label="ss") #ss
plt.xscale("log")
plt.yscale("log")

plt.xlim([0.1, 1000000])
plt.ylim([1, 300000])

plt.legend()

plt.xlabel(r"$^{12}C/^{13}C$")
plt.ylabel(r"$^{14}N/^{15}N$")

plt.title("Nitrogen/Carbon Ratios")

#plt.savefig('presn100comp.jpg', bbox_inches='tight')

plt.show()

# %%
results2 = []
with open("oxide-silicate-all.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results2.append(row)

for i,row in enumerate(results2):
    results2[i] = row[9], row[11]


data2 = []
for i,r in enumerate(results2[1:]):
    data2.append(r)

reals2 = []

for i in data2:
    if i[0] != '' and i[1] != '' and i[0] != '17O/16O' and i[0] != 'not measured':
        reals2.append((i[0], i[1]))

#print(reals)

d2 = [0] * len(reals2)

for j, row in enumerate(reals2):
    if row[0] != '17O/16O':
        d2[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data2 = np.array(d2)
#print(n_data2)

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data2[:,0], n_data2[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(o17o1620o[::25], o18o1620o[::25], color='b', marker = '.', label="Nonrotating 20M ")
plt.scatter(o17o1625o[::25], o18o1625o[::25], color='g', marker = '.', label="Nonrotating 25M ")
plt.scatter(o17o1632o[::25], o18o1632o[::25], color='orange', marker = '.', label="Nonrotating 32M ")
plt.scatter(o17o1640o[::25], o18o1640o[::25], color='k', marker = '.', label="Nonrotating 40M ")
plt.scatter(o17o1660o[::25], o18o1660o[::25], color='m', marker = '.', label="Nonrotating 60M ")
plt.scatter(o17o1685o[::25], o18o1685o[::25], color='purple', marker = '.', label="Nonrotating 85M ")
plt.scatter(o17o16120o[::25], o18o16120o[::25], color='lime', marker = '.', label="Nonrotating 120M ")
plt.scatter(o17o1620r[::25], o18o1620r[::25], color='darkslateblue', marker = '.', label="Rotating 20M ")
plt.scatter(o17o1625r[::25], o18o1625r[::25], color='darkgreen', marker = '.', label="Rotating 25M ")
plt.scatter(o17o1632r[::25], o18o1632r[::25], color='darkorange', marker = '.', label="Rotating 32M ")
plt.scatter(o17o1640r[::25], o18o1640r[::25], color='yellow', marker = '.', label="Rotating 40M ")
plt.scatter(o17o1660r[::25], o18o1660r[::25], color='darkviolet', marker = '.', label="Rotating 60M ")
plt.scatter(o17o1685r[::25], o18o1685r[::25], color='thistle', marker = '.', label="Rotating 85M ")
plt.scatter(o17o16120r[::25], o18o16120r[::25], color='dodgerblue', marker = '.', label="Rotating 120M ")
plt.scatter(o17r, o18r, color="cyan", marker='.', label="AGB Carbon Stars")
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.xlim([0.00001, .1])
plt.ylim([0.00001, .1])

plt.xlabel(r"$^{17}O/^{16}O$")
plt.ylabel(r"$^{18}O/^{16}O$")

plt.title("Oxygen Ratios")


plt.show()
