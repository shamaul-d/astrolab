# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

results = []
with open("SiC-All.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

for i,row in enumerate(results):
    results[i] = row[11], row[13]

data = []
for i,r in enumerate(results[1:]):
    data.append(r)

reals = []

for i in data:
    if i[0] != '' and i[1] != '' and i[0] != '12C/13C':
        reals.append((i[0], i[1]))

#print(reals)

d = [0] * len(reals)

for j, row in enumerate(reals):
    if row[0] != '12C/13C':
        d[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data = np.array(d)
#print(n_data)

# %%
results = []
with open("P025z14S0_abunds.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results.append(row)

t = [0] * len(results)        
        
for i,row in enumerate(results):
    results[i] = row[5:12]
    t[i] = row[12]

data1 = results[1:]

for j, row in enumerate(data1):
    data1[j] = [float(i) for i in row]

#title = results[0::8]
#C12 = data[0:]
#C13 = data[1:]
#N14 = data[2:]
#N15 = data[3:]
#O16 = data[4:]
#O17 = data[5:]
#O18 = data[6:]

n_data1 = np.array(data1)
#print(n_data.shape)

C12 = n_data1[:,0]
C13 = n_data1[:,1]
N14 = n_data1[:,2]
N15 = n_data1[:,3]
O16 = n_data1[:,4]
O17 = n_data1[:,5]
O18 = n_data1[:,6]

c12c13o = C12[:3221:50] / C13[:3221:50]
n14n15o =  N14[:3221:50] / N15[:3221:50]
o17o16o = O17[:3221:50] / O16[:3221:50]
o18o16o = O18[:3221:50] / O16[:3221:50]

c12c13b = C12[3221:4040:50] / C13[3221:4040:50]
n14n15b =  N14[3221:4040:50] / N15[3221:4040:50]
o17o16b = O17[3221:4040:50] / O16[3221:4040:50]
o18o16b = O18[3221:4040:50] / O16[3221:4040:50]

c12c13bs = C12[4040:6313:50] / C13[4040:6313:50]
n14n15bs =  N14[4040:6313:50] / N15[4040:6313:50]
o17o16bs = O17[4040:6313:50] / O16[4040:6313:50]
o18o16bs = O18[4040:6313:50] / O16[4040:6313:50]

c12c13ys = C12[6313:8559:50] / C13[6313:8559:50]
n14n15ys =  N14[6313:8559:50] / N15[6313:8559:50]
o17o16ys = O17[6313:8559:50] / O16[6313:8559:50]
o18o16ys = O18[6313:8559:50] / O16[6313:8559:50]

c12c13rs = C12[8559:12767:50] / C13[8559:12767:50]
n14n15rs =  N14[8559:12767:50] / N15[8559:12767:50]
o17o16rs = O17[8559:12767:50] / O16[8559:12767:50]
o18o16rs = O18[8559:12767:50] / O16[8559:12767:50]

c12c13ys2 = C12[12767:14262:50] / C13[12767:14262:50]
n14n15ys2 =  N14[12767:14262:50] / N15[12767:14262:50]
o17o16ys2 = O17[12767:14262:50] / O16[12767:14262:50]
o18o16ys2 = O18[12767:14262:50] / O16[12767:14262:50]

c12c13rs2 = C12[14262:18274:50] / C13[14262:18274:50]
n14n15rs2 =  N14[14262:18274:50] / N15[14262:18274:50]
o17o16rs2 = O17[14262:18274:50] / O16[14262:18274:50]
o18o16rs2 = O18[14262:18274:50] / O16[14262:18274:50]

c12c13ys3 = C12[18274:23009:50] / C13[18274:23009:50]
n14n15ys3 =  N14[18274:23009:50] / N15[18274:23009:50]
o17o16ys3 = O17[18274:23009:50] / O16[18274:23009:50]
o18o16ys3 = O18[18274:23009:50] / O16[18274:23009:50]

c12c13rs3 = C12[23009:23267:50] / C13[23009:23267:50]
n14n15rs3 =  N14[23009:23267:50] / N15[23009:23267:50]
o17o16rs3 = O17[23009:23267:50] / O16[23009:23267:50]
o18o16rs3 = O18[23009:23267:50] / O16[23009:23267:50]

c12c13w = C12[23279:] / C13[23279:]
n14n15w =  N14[23279:] / N15[23279:]
o17o16w = O17[23279:] / O16[23279:]
o18o16w = O18[23279:] / O16[23279:]


#print(c12c13)
#print(c12c13[:,0])

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data[:,0], n_data[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(c12c13o, n14n15o, color='b', marker = '.', label="Nonrotating 25M Otype Star")
plt.scatter(c12c13b, n14n15b, color='g', marker = '.', label="Nonrotating 25M Btype Star")
plt.scatter(c12c13bs, n14n15bs, color='orange', marker = '.', label="Nonrotating 25M BSG Star")
plt.scatter(c12c13ys, n14n15ys, color='k', marker = '.', label="Nonrotating 25M YSG Star")
plt.scatter(c12c13rs, n14n15rs, color='m', marker = '.', label="Nonrotating 25M RSG Star")
plt.scatter(c12c13ys2, n14n15ys2, color='k', marker = '.')
plt.scatter(c12c13rs2, n14n15rs2, color='m', marker = '.')
plt.scatter(c12c13ys3, n14n15ys3, color='k', marker = '.')
plt.scatter(c12c13rs3, n14n15rs3, color='m', marker = '.')
plt.scatter(c12c13w, n14n15w, color='purple', marker = '.', label="Nonrotating 25M WNL Star")
#plt.scatter([90],[500], marker="^", label="ss") #ss
plt.xscale("log")
plt.yscale("log")

plt.xlim([0.1, 1000000])
plt.ylim([1, 300000])

plt.legend()

plt.xlabel(r"$^{12}C/^{13}C$")
plt.ylabel(r"$^{14}N/^{15}N$")

plt.title("Nitrogen/Carbon Ratios")

#plt.savefig('presn100comp.jpg', bbox_inches='tight')

plt.show()

# %%
results2 = []
with open("oxide-silicate-all.csv") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader: # each row is a list
        results2.append(row)

for i,row in enumerate(results2):
    results2[i] = row[9], row[11]


data2 = []
for i,r in enumerate(results2[1:]):
    data2.append(r)

reals2 = []

for i in data2:
    if i[0] != '' and i[1] != '' and i[0] != '17O/16O' and i[0] != 'not measured':
        reals2.append((i[0], i[1]))

#print(reals)

d2 = [0] * len(reals2)

for j, row in enumerate(reals2):
    if row[0] != '17O/16O':
        d2[j] = [float(row[0]), float(row[1])]
    
#print(d)

n_data2 = np.array(d2)
#print(n_data2)

# %%
plt.figure(figsize=(10,6))

plt.scatter(n_data2[:,0], n_data2[:,1], color='r', marker = '.', label="Meteorite Grains")
plt.scatter(o17o16o, o18o16o, color='b', marker = '.', label="Nonrotating 25M Otype Star")
plt.scatter(o17o16b, o18o16b, color='g', marker = '.', label="Nonrotating 25M Btype Star")
plt.scatter(o17o16bs, o18o16bs, color='orange', marker = '.', label="Nonrotating 25M BSG Star")
plt.scatter(o17o16ys, o18o16ys, color='k', marker = '.', label="Nonrotating 25M YSG Star")
plt.scatter(o17o16rs, o18o16rs, color='m', marker = '.', label="Nonrotating 25M RSG Star")
plt.scatter(o17o16ys2, o18o16ys2, color='k', marker = '.')
plt.scatter(o17o16rs2, o18o16rs2, color='m', marker = '.')
plt.scatter(o17o16ys3, o18o16ys3, color='k', marker = '.')
plt.scatter(o17o16rs3, o18o16rs3, color='m', marker = '.')
plt.scatter(o17o16w, o18o16w, color='purple', marker = '.', label="Nonrotating 25M WNL Star")
#plt.scatter([90],[500], marker="^", label="ss") #ss
plt.xscale("log")
plt.yscale("log")
plt.legend()
plt.xlim([0.00001, .1])
plt.ylim([0.000001, .1])

plt.show()
